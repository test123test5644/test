# %% [markdown]
# <a href="https://colab.research.google.com/github/test123test5644/test/blob/main/%E8%A3%81%E5%89%AA%E8%87%AA%E5%B7%B1%E9%9B%B2%E7%AB%AF%E6%AA%94%E6%A1%88_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import os
import time
from google.colab import drive

# 挂载 Google Drive
drive.mount('/content/drive')

def get_first_file_in_directory(directory, exclude_file=None):
    """
    获取指定目录中的第一个文件的路径，可以排除指定的文件。

    :param directory: 目录路径。
    :param exclude_file: 要排除的文件名（可选）。
    :return: 第一个文件的完整路径。
    """
    files = [f for f in os.listdir(directory) if f != exclude_file]
    if not files:
        return None

    first_file = files[0]
    return os.path.join(directory, first_file)

def crop_image(input_image_path, output_image_path, crop_area):
    """
    裁剪图像到指定区域，并删除原始图像。

    :param input_image_path: 输入图像的路径。
    :param output_image_path: 保存裁剪后图像的路径。
    :param crop_area: 一个元组 (left, top, right, bottom)，指定裁剪区域。
    """
    with Image.open(input_image_path) as image:
        cropped_image = image.crop(crop_area)
        cropped_image.save(output_image_path)
        print(f"图像已保存到 {output_image_path}")

    # 删除原始图像
    os.remove(input_image_path)
    print(f"原始图像 {input_image_path} 已删除")

def process_images(directory_path, output_file_name, crop_area, num_iterations, wait_seconds):
    """
    定期检查目录，裁剪第一个图像并删除原始图像。

    :param directory_path: 目录路径。
    :param output_file_name: 输出文件名。
    :param crop_area: 一个元组 (left, top, right, bottom)，指定裁剪区域。
    :param num_iterations: 执行的次数。
    :param wait_seconds: 每次操作之间的等待时间（秒）。
    """
    output_path = os.path.join(directory_path, output_file_name)  # 输出路径

    for i in range(num_iterations):
        print(f"执行第 {i+1} 次操作...")

        # 获取目录中的第一个文件（排除输出文件）
        input_path = get_first_file_in_directory(directory_path, exclude_file=output_file_name)

        if input_path is None:
            print("目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。")
        else:
            # 裁剪图像并删除原始图像
            crop_image(input_path, output_path, crop_area)

        # 等待指定的秒数
        time.sleep(wait_seconds)

    print(f"{num_iterations} 次操作已完成。")

# 使用共享的 Google Drive 目录路径
directory_path = "/content/drive/My Drive/上傳檔案1/"  # 替换为你在共享 Google Drive 中的目录路径
output_file_name = "output.jpg"

# 定义裁剪区域 (左, 上, 右, 下)
crop_area = (300, 290, 493, 2800)

# 获取用户输入的执行次数和等待时间
num_iterations = int(input("请输入执行的次数: "))
wait_seconds = int(input("请输入每次操作之间的等待时间（秒）: "))

# 开始处理图像
process_images(directory_path, output_file_name, crop_area, num_iterations, wait_seconds)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 请输入执行的次数: 100
# 请输入每次操作之间的等待时间（秒）: 0
# 执行第 1 次操作...
# 图像已保存到 /content/drive/My Drive/上傳檔案/output.jpg
# 原始图像 /content/drive/My Drive/上傳檔案/387328.jpg 已删除
# 执行第 2 次操作...
# 图像已保存到 /content/drive/My Drive/上傳檔案/output.jpg
# 原始图像 /content/drive/My Drive/上傳檔案/387416.jpg 已删除
# 执行第 3 次操作...
# 图像已保存到 /content/drive/My Drive/上傳檔案/output.jpg
# 原始图像 /content/drive/My Drive/上傳檔案/388959.jpg 已删除
# 执行第 4 次操作...
# 图像已保存到 /content/drive/My Drive/上傳檔案/output.jpg
# 原始图像 /content/drive/My Drive/上傳檔案/387840.bmp 已删除
# 执行第 5 次操作...
# 图像已保存到 /content/drive/My Drive/上傳檔案/output.jpg
# 原始图像 /content/drive/My Drive/上傳檔案/387412.jpg 已删除
# 执行第 6 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 7 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 8 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 9 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 10 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 11 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 12 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 13 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 14 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 15 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 16 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 17 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 18 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 19 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 20 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 21 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 22 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 23 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 24 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 25 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 26 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 27 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 28 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 29 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 30 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 31 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 32 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 33 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 34 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 35 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 36 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 37 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 38 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 39 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 40 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 41 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 42 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 43 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 44 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 45 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 46 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 47 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 48 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 49 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 50 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 51 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 52 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 53 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 54 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 55 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 56 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 57 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 58 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 59 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 60 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 61 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 62 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 63 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 64 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 65 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 66 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 67 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 68 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 69 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 70 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 71 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 72 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 73 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 74 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 75 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 76 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 77 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 78 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 79 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 80 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 81 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 82 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 83 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 84 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 85 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 86 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 87 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 88 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 89 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 90 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 91 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 92 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 93 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 94 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 95 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 96 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 97 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 98 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 99 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 执行第 100 次操作...
# 目录中只有输出文件或没有可裁剪的文件，跳过裁剪操作。
# 100 次操作已完成。

# %%
# 列出 My Drive 下的文件夹
# !ls "/content/drive/My Drive/上傳的檔案地方/"
# Out:
#  output.jpg  'python 填值.gsheet'
